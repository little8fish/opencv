# %%
# %matplotlib inline

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import tools
import numpy as np

# %% [markdown]
# # 膨胀和腐蚀

# %%
img1 = cv.imread('/Users/dengjiacheng/PycharmProjects/opencv1/normal/image/beijing.jpg', 0)

# %%
img1.shape
# Out:
# (317, 352)

# %%
kernel = np.ones((5, 5), dtype=np.uint8)

# %%
erosion = cv.erode(img1, kernel)
dilate = cv.dilate(img1, kernel)

# %%
tools.show_more_img((1, 3), erosion, img1, dilate)
